# %% [markdown]
# BERT는 이미 누군가가 학습해둔 모델을 사용한다(pre-trained model)는 것을 뜻한다. 따라서 사용하는 model과 tokenizer는 항상 mapping 관계여야 한다. 예를 들어서 U 팀이 개발한 BERT를 사용하는데, V팀이 개발한 BERT의 tokenizer를 사용하면 model은 텍스트를 이해할 수 없다. U팀의 BERT의 토크나이저는 '우리'라는 단어를 23번으로 int encoding하는 반면에, V라는 BERT의 tokenizer는 '우리'라는 단어를 103번으로 int encoding해 단어와 mapping 되는 정보 자체가 달라지기 때문이다.

# %% [markdown]
# https://github.com/SKTBrain/KoBERT/tree/master/kobert_hf 의 kobert_tokenizer 폴더를 다운로드

# %%
# %pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Users/esilver/anaconda3/lib/python3.11/site-packages (23.2)
# Collecting pip
#   Obtaining dependency information for pip from https://files.pythonhosted.org/packages/50/c2/e06851e8cc28dcad7c155f4753da8833ac06a5c704c109313b8d5a62968a/pip-23.2.1-py3-none-any.whl.metadata
#   Downloading pip-23.2.1-py3-none-any.whl.metadata (4.2 kB)
# Downloading pip-23.2.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 7.6 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.2
#     Uninstalling pip-23.2:
#       Successfully uninstalled pip-23.2
# Successfully installed pip-23.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install git+https://git@github.com/SKTBrain/KoBERT.git@master
# Out:
# Collecting git+https://****@github.com/SKTBrain/KoBERT.git@master
#   Cloning https://****@github.com/SKTBrain/KoBERT.git (to revision master) to /private/var/folders/0y/g4ykw8915zj969f_nldwxbf40000gn/T/pip-req-build-8u91wkms
#   Running command git clone --filter=blob:none --quiet 'https://****@github.com/SKTBrain/KoBERT.git' /private/var/folders/0y/g4ykw8915zj969f_nldwxbf40000gn/T/pip-req-build-8u91wkms
#   Resolved https://****@github.com/SKTBrain/KoBERT.git to commit 47a69af87928fc24e20f571fe10c3cc9dd9af9a3
#   Preparing metadata (setup.py) ... done
# Collecting boto3<=1.15.18 (from kobert==0.2.3)
#   Using cached boto3-1.15.18-py2.py3-none-any.whl (129 kB)
# Collecting gluonnlp<=0.10.0,>=0.6.0 (from kobert==0.2.3)
#   Using cached gluonnlp-0.10.0.tar.gz (344 kB)
#   Preparing metadata (setup.py) ... done
# Collecting mxnet<=1.7.0.post2,>=1.4.0 (from kobert==0.2.3)
#   Using cached mxnet-1.7.0.post2-py3-none-macosx_10_13_x86_64.whl (30.2 MB)
# INFO: pip is looking at multiple versions of kobert to determine which version is compatible with other requirements. This could take a while.
# ERROR: Could not find a version that satisfies the requirement onnxruntime<=1.8.0,==1.8.0 (from kobert) (from versions: 1.15.0, 1.15.1)
# ERROR: No matching distribution found for onnxruntime<=1.8.0,==1.8.0
#
# [notice] A new release of pip is available: 23.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# https://github.com/SKTBrain/KoBERT 의 파일들을 다운

# %%
# %pip install git+https://git@github.com/SKTBrain/KoBERT.git@master

# %%
from kobert.pytorch_kobert import get_kobert_model
from kobert_tokenizer import KoBERTTokenizer
tokenizer = KoBERTTokenizer.from_pretrained('skt/kobert-base-v1')
bertmodel, vocab = get_kobert_model('skt/kobert-base-v1',tokenizer.vocab_file)

# %% [markdown]
# 4. 데이터셋 불러오기

# %% [markdown]
# 5. 입력 데이터셋 토큰화

# %%
""" 연예 뉴스 데이터셋 """
class EntNewsDataSet(Dataset):
    def __init__(self):
        # 데이터의 전처리를 해주는 부분
        self.titles
        self.labels = []
        self.sentences = []
        with open (infile, "r") as file:
            for line in file:
                line_count += 1

        with open (infile, "r") as file:
            for i, line in enumerate(tqdm(file, total=line_count, desc=f"Loading {infile}", unit=" lines")):
                data = json.loads(line)
                self.labels.append(data["label"])


    def __len__(self):
        # 데이터셋의 길이. 즉, 총 샘플의 수
        assert len(self.labels) == len(self.sentences)
        return len(self.labels)
    
    def __getitem__(self, index):
        # 데이터셋에서 특정 1개의 샘플을 가져오는 함수
        return (torch.tensor(self.labels[item]), 
        torch.tensor(self.sentences[item]))
